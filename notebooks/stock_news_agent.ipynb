# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %load_ext autoreload
# %autoreload 2

# %%
from agent.stock_news_agent import create_stock_news_agent
stock_news_graph = create_stock_news_agent()
# Out:
# EnvPath:D:\DevStudio\Repos\stock-news-agent\.env
# .env file loaded successfully

# %%
result= stock_news_graph.invoke({"ticker": "RKLB", "company_name": "", "sector":None, "industry": None})

# %%
from agent.utils.notebook_utilities import render_stock_news
render_stock_news(result)
# Out:
# # 📈 RKLB -  News
# **Sector**: None
# **Industry**:None
#
# ## 1. Space Stocks Slip Overnight After S&P Rejects SpaceX Fast-Track Inclusion Rules
#
# **Published date**: Thu, 04 Jun 2026 19:02:00 PDT
# **Sentiment**: ⚪ negative (score: -0.35)
# **URL**: [https://finance.yahoo.com/markets/stocks/articles/asts-rklb-rdw-sidu-slip-020226655.html](https://finance.yahoo.com/markets/stocks/articles/asts-rklb-rdw-sidu-slip-020226655.html)
#
# ### Summary
# SpaceX's record-breaking IPO faced a setback as S&P Global refused to change eligibility rules for the S&P 500. This decision removed a potential catalyst that could have triggered billions in passive fund buying, causing space stocks like RKLB and ASTS to slip overnight. While Nasdaq has made it easier for SpaceX to join its own index, investors remain concerned about SpaceX's financial viability given its recent net losses.
#
# ### Summary in Korean
# ...
