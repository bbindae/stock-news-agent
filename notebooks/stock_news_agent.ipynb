# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %load_ext autoreload
# %autoreload 2

# %%
from agent.stock_news_agent import create_stock_news_agent
stock_news_graph = create_stock_news_agent()
# Out:
# EnvPath:D:\DevStudio\Repos\stock-news-agent\.env
# .env file loaded successfully

# %%
from agent.utils.notebook_utilities import draw_graph
draw_graph(stock_news_graph)

# %%
result= stock_news_graph.invoke({"ticker": "APPL"})
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\output_parsers\json.py:88, in JsonOutputParser.parse_result(self, result, partial)
#      87 try:
# ---> 88     return parse_json_markdown(text)
#      89 except JSONDecodeError as e:
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\utils\json.py:163, in parse_json_markdown(json_string, parser)
#     162     json_str = json_string if match is None else match.group(2)
# --> 163 return _parse_json(json_str, parser=parser)
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\utils\json.py:191, in _parse_json(json_str, parser)
#     190 # Parse the JSON string into a Python dictionary
# --> 191 return parser(json_str)
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\utils\json.py:136, in parse_partial_json(s, strict)
#     133 # If we got here, we ran out of characters to remove
#     134 # and still couldn't parse the string as JSON, so return the parse error
#     135 # for the original string.
# --> 136 return json.loads(s, strict=strict)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\__init__.py:365, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     364     kw['parse_constant'] = parse_constant
# --> 365 return cls(**kw).decode(s)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result= stock_news_graph.invoke({"ticker": "RCL"})
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\pregel\main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
#    3882         config,
#    3883         context=context,
#    3884         stream_mode=(
#    3885             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3886         ),
#    3887         print_mode=print_mode,
#    3888         output_keys=output_keys,
#    3889         interrupt_before=interrupt_before,
#    3890         interrupt_after=interrupt_after,
#    3891         durability=durability,
#    3892         control=control,
#    3893         **kwargs,
#    3894     ):
#    3895         if stream_mode == "values":
#    3896             if len(chunk) == 2:
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\pregel\main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2934 for task in loop.match_cached_writes():
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#    2953 loop.after_tick()
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\pregel\_retry.py:585, in run_with_retry(task, retry_policy, configurable)
#     583     task.writes.clear()
#     584     # run the task
# --> 585     return task.proc.invoke(task.input, config)
#     586 except ParentCommand as exc:
#     587     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File d:\DevStudio\Repos\stock-news-agent\agent\nodes\summarize_news.py:77, in summarize_news(state)
#      73 llm_with_structure = llm.with_structured_output(NewsAnalysisList, method="json_mode")
#      75 chain = prompt_template | llm_with_structure
# ---> 77 response = chain.invoke({
#      78     "ticker": state.ticker,
#      79     "company_name": state.company_name,
#      80     "news_content": news_content
#      81 })
#      83 return {"news_items": response.articles}
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:3335, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3333                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3334             else:
# -> 3335                 input_ = context.run(step.invoke, input_, config)
#    3336 # finish the root run
#    3337 except BaseException as e:
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\output_parsers\base.py:207, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     199 @override
#     200 def invoke(
#     201     self,
#    (...)    204     **kwargs: Any,
#     205 ) -> T:
#     206     if isinstance(input, BaseMessage):
# --> 207         return self._call_with_config(
#     208             lambda inner_input: self.parse_result(
#     209                 [ChatGeneration(message=inner_input)]
#     210             ),
#     211             input,
#     212             config,
#     213             run_type="parser",
#     214         )
#     215     return self._call_with_config(
#     216         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     217         input,
#     218         config,
#     219         run_type="parser",
#     220     )
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:2238, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2234     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2235     with set_config_context(child_config) as context:
#    2236         output = cast(
#    2237             "Output",
# -> 2238             context.run(
#    2239                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2240                 func,
#    2241                 input_,
#    2242                 config,
#    2243                 run_manager,
#    2244                 **kwargs,
#    2245             ),
#    2246         )
#    2247 except BaseException as e:
#    2248     run_manager.on_chain_error(e)
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:486, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     484 if run_manager is not None and accepts_run_manager(func):
#     485     kwargs["run_manager"] = run_manager
# --> 486 return func(input, **kwargs)
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\output_parsers\base.py:208, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     199 @override
#     200 def invoke(
#     201     self,
#    (...)    204     **kwargs: Any,
#     205 ) -> T:
#     206     if isinstance(input, BaseMessage):
#     207         return self._call_with_config(
# --> 208             lambda inner_input: self.parse_result(
#     209                 [ChatGeneration(message=inner_input)]
#     210             ),
#     211             input,
#     212             config,
#     213             run_type="parser",
#     214         )
#     215     return self._call_with_config(
#     216         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     217         input,
#     218         config,
#     219         run_type="parser",
#     220     )
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\output_parsers\pydantic.py:75, in PydanticOutputParser.parse_result(self, result, partial)
#      58 """Parse the result of an LLM call to a Pydantic object.
#      59
#      60 Args:
#    (...)     72     The parsed Pydantic object.
#      73 """
#      74 try:
# ---> 75     json_object = super().parse_result(result)
#      76     return self._parse_obj(json_object)
#      77 except OutputParserException:
#
# File d:\DevStudio\Repos\stock-news-agent\.venv\Lib\site-packages\langchain_core\output_parsers\json.py:91, in JsonOutputParser.parse_result(self, result, partial)
#      89 except JSONDecodeError as e:
#      90     msg = f"Invalid json output: {text}"
# ---> 91     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: ### Article Analysis for Royal Caribbean Cruises Ltd (RCL)
#
# **Article ID: 0**
# - **title**: Cramer's lightning round: Buy Reddit - CNBC
# - **content_kr**: CNBC의 'Mad Money' 호스트 짐 크래머가 전화 청취자의 주식 질문에 대해 빠른 속도로 답변하는 '번개 라운드'를 진행했습니다. 스타우드 프로퍼티 트러스트, 랄리언트, 보그워너 등 여러 종목에 대한 의견을 밝혔으며, 레딧은 수익 배율 29배로 너무 비싸므로 한 번에 매수하기보다 천천히 접근해야 한다고 조언했습니다. 블루 오울 캐피탈과 같은 비즈니스 개발 회사에는 추천하지 않았습니다.
# - **summary**: This article features Jim Cramer's rapid-fire stock recommendations on CNBC, covering various sectors including real estate and technology but excluding the cruise industry entirely. The content focuses specifically on Reddit as a "unique property" that is currently overvalued at 29 times earnings, advising investors to buy slowly rather than aggressively. Other stocks like Borgwarner are described as parabolic winners, while Starwood Property Trust is criticized for poor performance. There is no mention of Royal Caribbean Cruises Ltd or any specific cruise line competitors in this segment.
# - **summary_kr**: 이 기사는 CNBC의 짐 크래머가 부동산과 기술 등 다양한 섹터에 대한 주식 추천을 다루며 유람선 산업은 전혀 언급하지 않습니다. 콘텐츠는 레딧이 수익 배율 29배로 과대평가되어 있다고 지적하고, 천천히 매수하라고 조언하는 데 집중합니다. 보그워너 같은 다른 종목들은 급등주라 평가받았고 스타우드 프로퍼티 트러스트는 성과가 좋지 않다고 비판되었습니다. 이 섹먼트에는 로열 카리비언 크루이즈 리미티드나 유람선 경쟁사들에 대한 언급이 없습니다.
# - **sentiment_label**: Neutral
# - **sentiment_score**: 0.1
#
# **Article ID: 1**
# - **title**: Jim Cramer's top 10 things to watch in the stock market Friday - CNBC
# - **content_kr**: 짐 크래머는 금요일 시장 관찰 목록에서 테크 매각이 아시아와 유럽으로 퍼지며 나스닥과 S&P 500 이 하락할 것으로 예상했습니다. 루루레몬은 실적이 부진하고 guidance 를 낮췄으며, 스페이스X 가 S&P 500 에 조기 진입하지 못하게 결정된 점도 언급되었습니다. 크라우드스트라이크는 기대 이상의 실적과 전망을 발표했으나 주가는 하락했고, 파인즈 벨로우와 치폴레 등 소매 및 식음료 기업들의 평가가 조정되거나 유지되었습니다. 코비네이스의 암호화폐 거래량 감소로 인해 부정적인 전망이 나왔으며, 퀄컴에 대해서는 긍정적 촉매를 예상했습니다.
# - **summary**: The article outlines Jim Cramer's top 10 market watchlist for Friday, highlighting a broader tech sell-off and specific earnings misses or downgrades in retail (Lululemon) and crypto sectors (Coinbase). It notes that S&P Global excluded SpaceX from early index entry but maintains focus on enterprise software like Salesforce. While the cruise industry is not explicitly mentioned, the article discusses macroeconomic factors such as strong jobs data driving Treasury yields up to 4.53%, which could impact discretionary spending for travel and leisure sectors generally.
# - **summary_kr**: 이 기사는 금요일 시장 관찰 목록에서 테크 매각과 소매 (루루레몬), 암호화폐 섹터의 실적 부진 등을 강조하며 유람선 산업을 명시적으로 언급하지는 않습니다. 스페이스X 가 S&P 500 에서 제외된 점과 엔터프라이즈 소프트웨어에 대한 관심도 다루었습니다. 유람선 산업은 직접 언급되지 않았으나, 강력한 고용 데이터로 인해 국채 수익률이 상승하는 등 거시경제 요인이 여행 및 레저 섹터를 전반적으로 영향을 줄 수 있음을 시사합니다.
# - **sentiment_label**: Neutral
# - **sentiment_score**: 0.2
#
# **Article ID: 2**
# - **title**: Stock Market Today: Dow, S&P 500 and Nasdaq set to fall ahead of jobs report as tech enthusiasm dulls - MarketWatch
# - **content_kr**: 시장 전망은 금요일 고용 보고서 발표 전 도우, S&P 500 과 나스닥 지수가 하락할 것으로 예상됩니다. 테크 주식에 대한 열기가 식었으며, 스페이스X 가 S&P 500 에서 조기 진입을 허용받지 못했다는 결정이 투자자들의 반응을 이끌었습니다. 또한 루루레몬의 판매 감소와 '6 월 우울증' 가능성 등 시장 한계 테스트가 언급되었습니다.
# - **summary**: This news piece reports on market futures declining ahead of a jobs report, driven by dulling tech enthusiasm and the specific decision to exclude SpaceX from early S&P 500 entry. The article highlights broader concerns about retail struggles (Lululemon) and potential volatility in June for the S&P 500. While Royal Caribbean Cruises Ltd is not named, the context of a weakening consumer sentiment due to tech sell-offs and cautious commentary on retailers suggests a challenging macroeconomic environment that could negatively impact discretionary travel spending associated with cruise lines.
# - **summary_kr**: 이 뉴스는 고용 보고서 발표 전 테크 열기 둔화와 스페이스X 의 S&P 500 제외 결정으로 인해 시장 지수가 하락할 것으로 보고합니다. 루루레몬의 판매 감소와 6 월 시장의 불안정성 등 광범위한 우려가 언급되었습니다. 로열 카리비언 크루이즈 리미티드는 명시적으로 언급되지 않았으나, 테크 매각과 소매 부진으로 인한 소비 심리 약화는 유람선 같은 선택적 여행 지출에 부정적인 거시경제 환경을 시사합니다.
# - **sentiment_label**: Negative
# - **sentiment_score**: -0.3
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE
# During task with name 'summarize_news' and id 'eeef1e50-2320-72a6-f388-01f611f3b6dd'

# %%
from agent.utils.notebook_utilities import render_stock_news
render_stock_news(result)
# Out:
# # 📈 NVDA - NVIDIA Corporation News
# **Sector**: Technology
# **Industry**:Semiconductors
#
# ## 1. Chip Selloff Erases Over $1 Trillion in Market Value Amid Broadcom Weakness
#
# **Published date**: Fri, 05 Jun 2026 13:05:58 PDT
# **Sentiment**: ⚪ negative (score: -0.78)
# **URL**: [https://www.reuters.com/business/media-telecom/chip-selloff-erases-over-1-trillion-stock-market-value-2026-06-05/](https://www.reuters.com/business/media-telecom/chip-selloff-erases-over-1-trillion-stock-market-value-2026-06-05/)
#
# ### Summary
# U.S.-traded chipmakers suffered massive losses on Friday after Broadcom's weak quarterly report reverberated across Wall Street. Nvidia alone lost over $300 billion in market capitalization, while Micron and AMD also tumbled significantly as investors grew concerned about high valuations. The selloff was exacerbated by worries regarding higher interest rates following strong jobs data.
#
# ### 요약
# 브로드컴의 약한 분기 실적 발표가 월스트리트에 연쇄적으로 영향을 미치며 미국 상장 반도체 기업들이 큰 손실을 입었습니다. 엔비디아만 시장 가치를 3000억 달러 이상 잃었고, 마이크론과 AMD도 크게 하락했습니다.
#
# ### content
# \# Chip selloff erases over $1 trillion in stock market value. Item 1 of 2 Computer motherboard and chip appear in this illustration taken August 25, 2025. Computer motherboard and chip appear in this illustration taken August 25, 2025. June 5 (Reuters) - U.S.-traded chipmakers plunged on Friday, losing over $1 trillion in market value, with deep losses in AI heavy hitters ​including Nvidia (NVDA.O), opens new tab, Micron Technology (MU.O), opens new tab and Advanced Micro Devices (AMD.O), opens new tab, as ‌Broadcom's (AVGO.O), opens new tab weak report earlier this week reverberated across Wall Street. The PHLX chip index (.SOX), opens new tab slumped almost 8.5% in afternoon trading, putting it on track for its ​deepest one-day loss since Wall Street's "Liberation Day" tariff selloff ​in April 2025. Friday's selloff added to losses on Thursday after ⁠Broadcom gave a quarterly report that showed demand for its ​custom AI chips business falling short of lofty expectations.
#
# ### 내용
# 브로드컴의 약한 실적 발표가 연쇄적으로 영향을 미치며 반도체 기업들이 큰 손실을 입었습니다. 엔비디아는 6% 하락하여 시장 가치를 3000억 달러 이상 잃었고, 마이크론과 AMD도 각각 11%, 10.5% 급락했습니다.
#
# -------------------------------------------------------------
#
# ## 2. Major Chip Stocks Fall for Second Day Following Broadcom's Soft AI Guidance
#
# **Published date**: Fri, 05 Jun 2026 02:10:09 PDT
# **Sentiment**: ⚪ negative (score: -0.65)
# **URL**: [https://finance.yahoo.com/markets/stocks/articles/nvda-intc-amd-mu-major-091009058.html](https://finance.yahoo.com/markets/stocks/articles/nvda-intc-amd-mu-major-091009058.html)
#
# ### Summary
# Broadcom's softer-than-expected guidance for its custom AI chip business triggered a significant sell-off in the semiconductor sector. Major stocks like Nvidia, Intel, AMD, and Micron fell sharply on Friday following Broadcom's report released earlier that week. The decline signals profit-taking after months of strong gains driven by surging demand for AI accelerators. Retail investor sentiment turned extremely bearish as seen on social trading platforms.
#
# ### 요약
# 브로드컴의 맞춤형 AI 칩 사업에 대한 예상보다 약한 전망 발표로 인해 반도체 섹터에서 큰 매도세가 발생했습니다. 브로드컴이 이번 주早些时候 발표한 실적 이후 엔비디아, 인텔, AMD 및 마이크론 등 주요 주식들이 급락했습니다. 이는 수개월간 AI 가속기 수요 증가로 인한 강력한 상승세 후 이익 실현을 의미합니다.
#
# ### content
# \# NVDA, INTC, AMD, MU: Major Chip Stocks Fall For Second Day After AVGO's Soft AI Guidance. * Micron shares fell 3.3%, leading the declines in the chips space. * Major chip stocks declined for a second day after Broadcom’s results. * Stocktwits sentiment for SOXX dropped lower in the ‘extremely bearish’ zone. Micron shares fell 3.3% in premarket trading on Friday, leading declines in semiconductor stocks for a second day after a softer-than-expected outlook from chip giant Broadcom triggered a global selloff in semiconductor stocks. Intel stock dropped 2.8%, and Advanced Micro Devices shares fell 2.8% for a second day. The move signals profit taking and a reset of sentiment in the chip space, after major stocks ran up sharply in recent months on surging demand for AI accelerators amid a rapid buildout of new data centers. On Stocktwits, the retail sentiment for SOXX fell even lower in the ‘extremely bearish’ zone (8/100).
#
# ### 내용
# 브로드컴의 예상보다 약한 인공지능(AI) 관련 전망 발표로 인해 엔비디아(NVDA), 인텔(INTC), AMD 및 마이크론(MU) 등 주요 반도체 주식들이 두 번째 거래일 연속 하락했습니다. 브로드컴은 3 분기 AI 칩 매출에 대한 전망을 낮게 제시하여 투자자들의 우려를 불러일으켰고, 이는 전 세계적 반도체 매물로 이어졌습니다.
#
# -------------------------------------------------------------
#
# ## 3. Apple to Use Nvidia Chips for Redesigned Siri Assistant via Google Cloud
#
# **Published date**: Thu, 04 Jun 2026 12:22:54 PDT
# **Sentiment**: ⚪ positive (score: 0.72)
# **URL**: [https://finance.yahoo.com/sectors/technology/articles/huge-news-apple-nvidia-stock-192254243.html](https://finance.yahoo.com/sectors/technology/articles/huge-news-apple-nvidia-stock-192254243.html)
#
# ### Summary
# Apple is reportedly preparing to integrate Nvidia's Blackwell B200 chips into its upgraded Siri assistant for handling complex user requests. This development involves leveraging Google Cloud infrastructure while keeping sensitive tasks on Apple-controlled servers, marking a strategic shift in their AI capabilities. The move highlights ongoing collaboration trends among major tech platforms as they scale advanced artificial intelligence features ahead of upcoming developer conferences.
#
# ### 요약
# 애플은 복잡한 사용자 요청을 처리하기 위해 엔비디아의 블랙웰 B200 칩을 차세대 시리 어시스턴트에 통합할 계획입니다. 민감한 작업은 애플 서버에서, 더 무거운 워크로드는 구글 클라우드를 활용하는 하이브리드 AI 전략으로 전환됩니다.
#
# ### content
# 2. Best 0% APR cards. 3. Best balance transfer cards. 2. Best high-yield savings accounts. 3. Best money market accounts. 4. Best free checking accounts. 3. How to get approved. \# Huge News For Apple and Nvidia Stock Investors. Apple (NASDAQ:AAPL) is preparing a redesigned version of its Siri assistant that may rely partly on Nvidia (NASDAQ:NVDA) Blackwell B200 chips hosted through Google (NASDAQ:GOOG) infrastructure, marking a potential shift in how the company powers advanced AI features. The upgraded Siri system is expected to handle more complex user requests using high-performance Nvidia processors, while leveraging Google Cloud for portions of its computing workload. Apple's AI framework still includes its Private Cloud Compute system, introduced in 2024, which processes sensitive tasks through Apple-controlled servers. Smaller queries continue to be handled directly on devices, while heavier workloads may be routed to external compute partners depending on demand. Nvidia chips and Google cloud services are expected to play a supporting role in scaling Siri's upgraded capabilities, though Apple has not confirmed specific technical details.
#
# ### 내용
# 애플이 차세대 시리(Siri) 어시스턴트를 위해 엔비디아의 블랙웰 칩을 활용하고 구글 클라우드 인프라를 사용할 계획입니다. 이는 애플이 민감한 작업은 자체 서버에서 처리하되, 더 복잡한 요청에는 외부 파트너인 엔비디아가 참여하는 하이브리드 AI 전략으로 보입니다.
#
# -------------------------------------------------------------
